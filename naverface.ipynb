# %% [markdown]
# <a href="https://colab.research.google.com/github/goldenkiwi-hyeuk/202112python/blob/main/naverface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Client ID : asc5opmDC4lpX4Fjl_6O
# Client Secret : 6lVeWkmJAc

# %%
# 분석
import os
import sys
import requests
client_id = "asc5opmDC4lpX4Fjl_6O"
client_secret = "6lVeWkmJAc"

url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
# url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식

files = {'image': open('family.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":1200,"height":847},"faceCount":7},"faces":[{"roi":{"x":341,"y":279,"width":60,"height":60},"landmark":{"leftEye":{"x":357,"y":292},"rightEye":{"x":384,"y":295},"nose":{"x":370,"y":308},"leftMouth":{"x":358,"y":324},"rightMouth":{"x":381,"y":325}},"gender":{"value":"male","confidence":0.999998},"age":{"value":"31~35","confidence":0.577669},"emotion":{"value":"neutral","confidence":0.999998},"pose":{"value":"frontal_face","confidence":0.999404}},{"roi":{"x":836,"y":266,"width":59,"height":59},"landmark":{"leftEye":{"x":856,"y":284},"rightEye":{"x":882,"y":282},"nose":{"x":870,"y":298},"leftMouth":{"x":859,"y":313},"rightMouth":{"x":882,"y":311}},"gender":{"value":"male","confidence":0.999996},"age":{"value":"38~42","confidence":0.331422},"emotion":{"value":"smile","confidence":0.747392},"pose":{"value":"frontal_face","confidence":0.995238}},{"roi":{"x":518,"y":251,"width":51,"height":51},"landmark":{"leftEye":{"x":532,"y":263},"rightEye":{"x":554,"y":264},"nose
# ...

# %%
import matplotlib.pyplot as plt   # 그림 관련 라이브러리
import matplotlib.image as mping  # 사진 관련 라이브러리

img = mping.imread('family.jpg')

plt.imshow(img)

# %%
import json

parsed = json.loads(response.text)  #response은 넘어온 객체
# json.loads를 통해 딕셔너리 형태로 변환
print(json.dumps(parsed,  indent=4))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 1200,
#             "height": 847
#         },
#         "faceCount": 7
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 341,
#                 "y": 279,
#                 "width": 60,
#                 "height": 60
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 357,
#                     "y": 292
#                 },
#                 "rightEye": {
#                     "x": 384,
#                     "y": 295
#                 },
#                 "nose": {
#                     "x": 370,
#                     "y": 308
#                 },
#                 "leftMouth": {
#                     "x": 358,
#                     "y": 324
#                 },
#                 "rightMouth": {
#                     "x": 381,
#                     "y": 325
#                 }
#             },
#             "gender": {
# ...

# %%
# dict 다루기
# 딕셔너리는 순서가 없다. so. 인덱싱 불가 & 슬라이싱 불가
dict = {'Name': 'pink', 'Age':23, 'Class':['beginner','blog']}
dict
# Out:
# {'Age': 23, 'Class': ['beginner', 'blog'], 'Name': 'pink'}

# %%
# 키값들만 추출
dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
# 밸류값들만 추출
dict.values()
# Out:
# dict_values(['pink', 23, ['beginner', 'blog']])

# %%
dict['Class']
# Out:
# ['beginner', 'blog']

# %%
dict.get('Class')
# Out:
# ['beginner', 'blog']

# %%
# 키값으로 접근은 키가 없으면 오류를 발생시킴
dict['Cls']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-3a7882c83805> in <module>()
#       1 # 키값으로 접근은 키가 없으면 오류를 발생시킴
# ----> 2 dict['Cls']
#
# KeyError: 'Cls'

# %%
# get으로 접근시 키가 없으면 그냥 아무것도 반환안함
dict.get('Cls')

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
parsed['info']
# Out:
# {'faceCount': 7, 'size': {'height': 847, 'width': 1200}}

# %%
parsed['faces']
# Out:
# [{'age': {'confidence': 0.577669, 'value': '31~35'},
#   'emotion': {'confidence': 0.999998, 'value': 'neutral'},
#   'gender': {'confidence': 0.999998, 'value': 'male'},
#   'landmark': {'leftEye': {'x': 357, 'y': 292},
#    'leftMouth': {'x': 358, 'y': 324},
#    'nose': {'x': 370, 'y': 308},
#    'rightEye': {'x': 384, 'y': 295},
#    'rightMouth': {'x': 381, 'y': 325}},
#   'pose': {'confidence': 0.999404, 'value': 'frontal_face'},
#   'roi': {'height': 60, 'width': 60, 'x': 341, 'y': 279}},
#  {'age': {'confidence': 0.331422, 'value': '38~42'},
#   'emotion': {'confidence': 0.747392, 'value': 'smile'},
#   'gender': {'confidence': 0.999996, 'value': 'male'},
#   'landmark': {'leftEye': {'x': 856, 'y': 284},
#    'leftMouth': {'x': 859, 'y': 313},
#    'nose': {'x': 870, 'y': 298},
#    'rightEye': {'x': 882, 'y': 282},
#    'rightMouth': {'x': 882, 'y': 311}},
#   'pose': {'confidence': 0.995238, 'value': 'frontal_face'},
# ...

# %%
parsed['faces'][0]
# Out:
# {'age': {'confidence': 0.577669, 'value': '31~35'},
#  'emotion': {'confidence': 0.999998, 'value': 'neutral'},
#  'gender': {'confidence': 0.999998, 'value': 'male'},
#  'landmark': {'leftEye': {'x': 357, 'y': 292},
#   'leftMouth': {'x': 358, 'y': 324},
#   'nose': {'x': 370, 'y': 308},
#   'rightEye': {'x': 384, 'y': 295},
#   'rightMouth': {'x': 381, 'y': 325}},
#  'pose': {'confidence': 0.999404, 'value': 'frontal_face'},
#  'roi': {'height': 60, 'width': 60, 'x': 341, 'y': 279}}

# %%
 parsed['faces'][0]['age']
# Out:
# {'confidence': 0.577669, 'value': '31~35'}

# %%
parsed['faces'][0]['gender']
# Out:
# {'confidence': 0.999998, 'value': 'male'}

# %%
parsed['faces'][0]['emotion']
# Out:
# {'confidence': 0.999998, 'value': 'neutral'}

# %%
parsed['faces'][0]['roi']
# Out:
# {'height': 60, 'width': 60, 'x': 341, 'y': 279}

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt


imp = mping.imread('family.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

for each in parsed['faces']:
  x,y,w,h = each['roi'].values()
  gender, gender_c = each['gender'].values()
  emotion, emotion_c = each['emotion'].values()
  age, age_c = each['age'].values()

  rect_face = patches.Rectangle((x,y),w,h,
                                edgecolor = 'r', 
                                facecolor = 'none',
                                )
  anno = gender + ','  + '\n' + age + ',' + '\n' + emotion + ',' +  '\n'
  plt.text(x,y + h + 100, anno, color = 'blue')
  ax.add_patch(rect_face)

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt


img = mping.imread('family.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

for each in parsed['faces']:
  x,y,w,h = each['roi'].values()
  gender, gender_c = each['gender'].values()
  emotion, emotion_c = each['emotion'].values()
  age, age_c = each['age'].values()

  rect_face = patches.Rectangle((x,y),w,h,
                                edgecolor = 'r', 
                                facecolor = 'none',
                                )
  anno = gender + ','  + str(gender_c) +'\n' + age + ',' + str(age_c) +  '\n' + emotion + ',' + str(emotion_c) +'\n'
  plt.text(x,y + h + 100, anno, color = 'blue')
  ax.add_patch(rect_face)

# %%
# 분석
import os
import sys
import requests

client_id = "asc5opmDC4lpX4Fjl_6O"
client_secret = "6lVeWkmJAc"

url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
# url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식

files = {'image': open('friend.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":1440,"height":1080},"faceCount":8},"faces":[{"roi":{"x":754,"y":470,"width":121,"height":121},"landmark":{"leftEye":{"x":779,"y":497},"rightEye":{"x":828,"y":494},"nose":{"x":792,"y":531},"leftMouth":{"x":784,"y":557},"rightMouth":{"x":831,"y":548}},"gender":{"value":"female","confidence":0.943939},"age":{"value":"17~21","confidence":0.39437},"emotion":{"value":"neutral","confidence":0.999991},"pose":{"value":"frontal_face","confidence":0.675695}},{"roi":{"x":616,"y":251,"width":93,"height":93},"landmark":{"leftEye":{"x":638,"y":280},"rightEye":{"x":677,"y":266},"nose":{"x":659,"y":301},"leftMouth":{"x":650,"y":320},"rightMouth":{"x":688,"y":308}},"gender":{"value":"female","confidence":0.999938},"age":{"value":"22~26","confidence":0.394326},"emotion":{"value":"smile","confidence":0.999356},"pose":{"value":"frontal_face","confidence":0.983652}},{"roi":{"x":957,"y":252,"width":125,"height":125},"landmark":null,"gender":{"value":"female","confidence":0.977674},
# ...

# %%
parsed = json.loads(response.text)  #response은 넘어온 객체
# json.loads를 통해 딕셔너리 형태로 변환
print(json.dumps(parsed,  indent=4))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 1440,
#             "height": 1080
#         },
#         "faceCount": 8
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 754,
#                 "y": 470,
#                 "width": 121,
#                 "height": 121
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 779,
#                     "y": 497
#                 },
#                 "rightEye": {
#                     "x": 828,
#                     "y": 494
#                 },
#                 "nose": {
#                     "x": 792,
#                     "y": 531
#                 },
#                 "leftMouth": {
#                     "x": 784,
#                     "y": 557
#                 },
#                 "rightMouth": {
#                     "x": 831,
#                     "y": 548
#                 }
#             },
#             "gender": {
# ...

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt


img = mping.imread('friend.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

for each in parsed['faces']:
  x,y,w,h = each['roi'].values()
  gender, gender_c = each['gender'].values()
  emotion, emotion_c = each['emotion'].values()
  age, age_c = each['age'].values()

  rect_face = patches.Rectangle((x,y),w,h,
                                edgecolor = 'r', 
                                facecolor = 'none',
                                )
  anno = gender + ','  + str(gender_c) +'\n' + age + ',' + str(age_c) +  '\n' + emotion + ',' + str(emotion_c) +'\n'
  plt.text(x,y + h + 100, anno, color = 'blue')
  ax.add_patch(rect_face)

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt


img = mping.imread('friend.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

for each in parsed['faces']:
  x,y,w,h = each['roi'].values()
  gender, gender_c = each['gender'].values()
  emotion, emotion_c = each['emotion'].values()
  age, age_c = each['age'].values()

  rect_face = patches.Rectangle((x,y),w,h,
                                edgecolor = 'r', 
                                facecolor = 'none',
                                )
  anno = gender + ','  + '\n' + age + ',' + '\n' + emotion + ',' +  '\n'
  plt.text(x,y + h + 100, anno, color = 'blue')
  ax.add_patch(rect_face)

# %%
# 분석
import os
import sys
import requests

client_id = "asc5opmDC4lpX4Fjl_6O"
client_secret = "6lVeWkmJAc"

# url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식

files = {'image': open('leejungi.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":560,"height":840},"faceCount":1},"faces":[{"celebrity":{"value":"이준기","confidence":0.741221}}]}

# %%
parsed = json.loads(response.text)  #response은 넘어온 객체
# json.loads를 통해 딕셔너리 형태로 변환
print(json.dumps(parsed,  indent=4))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 560,
#             "height": 840
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "\uc774\uc900\uae30",
#                 "confidence": 0.741221
#             }
#         }
#     ]
# }

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

img = mping.imread('leejungi.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

a,b = parsed["faces"][0]['celebrity'].values()

b = round(b*100)


# k = "연예인 {}를 {}%의 확률로 닮았습니다.".format(a,b)
# anno = k.decode("utf-8")
anno = "연예인 {}를 {}%의 확률로 닮았습니다.".format(a,b)
plt.text(100, 600, anno, color = 'red', size = 15)
# Out:
# Text(100, 600, '연예인 이준기를 74%의 확률로 닮았습니다.')

# %%
# 분석
import os
import sys
import requests

client_id = "asc5opmDC4lpX4Fjl_6O"
client_secret = "6lVeWkmJAc"

# url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식

files = {'image': open('me.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":1080,"height":1440},"faceCount":1},"faces":[{"celebrity":{"value":"엄기준","confidence":0.160574}}]}
